# %% [markdown]
# <a href="https://colab.research.google.com/github/andysontran/21-CHL5230-F23/blob/main/21_CHL5230_F23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CHL5230H (F23): Datathon 3 - Project Phase 2
# Team Members:
#   No_21:  Son Tran

# Dataset Used:
#   CHL5230 dataset (diabetes.csv)
#     Attribute	Description:
#

# %% [markdown]
# # 1 File Input

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Clone files on Githyb repository to Drive
# !git clone https://github.com/andysontran/21-CHL5230-F23.git

# Set working directory
# %cd 21-CHL5230-F23/
# Out:
# Mounted at /content/drive
# Cloning into '21-CHL5230-F23'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), 634.31 KiB | 3.02 MiB/s, done.
# /content/21-CHL5230-F23

# %%
# Load the CHL5230 dataset into a Pandas df
import pandas as pd

data = pd.read_csv('diabetes.csv')
data
# Out:
#       Age_at_Exam    sBP             sBP_Date   BMI             BMI_Date  LDL  \
# 0            53.0  123.0  2015-06-30 00:00:00  23.0  2015-06-30 00:00:00  3.9
# 1            67.0  109.0  2015-06-30 00:00:00  22.0  2015-04-29 00:00:00  3.1
# 2            59.0  117.0  2015-06-30 00:00:00  21.0  2015-06-30 00:00:00  2.6
# 3            45.0  133.0  2015-06-30 00:00:00  26.2  2014-09-29 00:00:00  3.0
# 4            82.0  138.0  2015-06-30 00:00:00  39.0  2015-06-30 00:00:00  2.0
# ...           ...    ...                  ...   ...                  ...  ...
# 9995         49.0   90.0  2004-05-05 00:00:00  36.4  2004-01-09 00:00:00  1.9
# 9996         61.0  110.0  2004-04-27 00:00:00  27.4  2004-03-16 00:00:00  4.4
# 9997         46.0  135.0  2004-04-21 00:00:00  31.4  2004-01-07 00:00:00  2.3
# 9998         40.0  130.0  2004-03-18 00:00:00  32.8  2004-03-18 00:00:00  2.8
# 9999         70.0  140.0  2004-02-02 00:00:00  27.5  2003-10-02 00:00:00  2.7
#
#                  LDL_Date  HDL             HDL_Date  A1c  ...  \
# 0     2015-04-23 00:00:00  1.9  2015-04-23 00:00:00  5.6  ...
# 1     2015-04-16 00:00:00  1.8  2015-04-16 00:00:00  5.6  ...
# 2     2015-06-15 00:00:00  2.9  2015-06-15 00:00:00  5.6  ...
# 3     2015-04-15 00:00:00  1.6  2015-04-15 00:00:00  5.8  ...
# 4     2015-04-07 00:00:00  1.9  2015-04-07 00:00:00  5.8  ...
# ...                   ...  ...                  ...  ...  ...
# 9995  2005-01-26 00:00:00  1.1  2005-01-26 00:00:00  6.0  ...
# 9996  2004-06-01 00:00:00  1.2  2004-06-01 00:00:00  5.4  ...
# 9997  2004-01-30 00:00:00  0.9  2004-01-30 00:00:00  5.2  ...
# 9998  2004-03-26 00:00:00  0.9  2004-03-26 00:00:00  6.2  ...
# 9999  2004-01-03 00:00:00  2.0  2004-01-03 00:00:00  5.6  ...
#
#      leastO(A1c_Date)  leastO(DM_OnsetDate) leastO(FBS_Date)  LeastOfAll  \
# 0                 NaN                   NaN              NaN         NaN
# 1                 NaN                   NaN              NaN         NaN
# 2                 NaN                   NaN              NaN         NaN
# 3                 NaN                   NaN              NaN         NaN
# 4                 NaN                   NaN              NaN         NaN
# ...               ...                   ...              ...         ...
# 9995          42025.0               42004.0          42124.0     42004.0
# 9996              NaN                   NaN              NaN         NaN
# 9997              NaN                   NaN              NaN         NaN
# 9998          41964.0               38072.0          41964.0     38072.0
# 9999              NaN                   NaN              NaN         NaN
#
#      A1C_BEF_DM  FBS_BEF_DM    Patient_ID     DM_Onset_Revised  \
# 0           NaN         NaN  4.001000e+15                  NaN
# 1           NaN         NaN  4.001000e+15                  NaN
# 2           NaN         NaN  2.001000e+15                  NaN
# 3           NaN         NaN  4.001000e+15                  NaN
# 4           NaN         NaN  4.001000e+15                  NaN
# ...         ...         ...           ...                  ...
# 9995      False       False  8.001001e+15  2014-12-24 00:00:00
# 9996        NaN         NaN  2.001000e+15                  NaN
# 9997        NaN         NaN  2.001000e+15                  NaN
# 9998      False       False  2.001000e+15  2004-03-19 00:00:00
# 9999        NaN         NaN  2.001000e+15                  NaN
#
#       DM_Onset_Revised_1YrPrior DIABETES
# 0                           NaN       No
# 1                           NaN       No
# 2                           NaN       No
# 3                           NaN       No
# 4                           NaN       No
# ...                         ...      ...
# 9995        2013-12-24 00:00:00      Yes
# 9996                        NaN       No
# 9997                        NaN       No
# 9998        2003-03-19 00:00:00      Yes
# 9999                        NaN       No
#
# [10000 rows x 43 columns]

# %%
# Checking data types
data.dtypes
# Out:
# Age_at_Exam                                float64
# sBP                                        float64
# sBP_Date                                    object
# BMI                                        float64
# BMI_Date                                    object
# LDL                                        float64
# LDL_Date                                    object
# HDL                                        float64
# HDL_Date                                    object
# A1c                                        float64
# A1c_Date                                    object
# TG                                         float64
# TG_Date                                     object
# FBS                                        float64
# FBS_Date                                    object
# FBS>DM                                     float64
# Total_Cholesterol                          float64
# Total_Cholesterol_Lab_Date                  object
# Diabetes                                   float64
# DM_OnsetDate                                object
# Depression                                 float64
# Depression_OnsetDate                        object
# HTN                                        float64
# HTN_OnsetDate                               object
# OA                                         float64
# OA_OnsetDate                                object
# COPD                                       float64
# COPD_Date                                   object
# Hypertension_Medications                    object
# Hypertension_Medications_First_Instance     object
# Corticosteroids                             object
# Corticosteroids_first_instance              object
# Sex                                         object
# leastO(A1c_Date)                           float64
# leastO(DM_OnsetDate)                       float64
# leastO(FBS_Date)                           float64
# LeastOfAll                                 float64
# A1C_BEF_DM                                  object
# FBS_BEF_DM                                  object
# Patient_ID                                 float64
# DM_Onset_Revised                            object
# DM_Onset_Revised_1YrPrior                   object
# DIABETES                                    object
# dtype: object

# %%
# Checking for any NA values
print(data.shape)
print(data.isna().sum())
# Out:
# (10000, 43)
# Age_at_Exam                                   0
# sBP                                           4
# sBP_Date                                      0
# BMI                                           0
# BMI_Date                                      0
# LDL                                          61
# LDL_Date                                      0
# HDL                                          72
# HDL_Date                                     64
# A1c                                           0
# A1c_Date                                      0
# TG                                           53
# TG_Date                                      42
# FBS                                           0
# FBS_Date                                      0
# FBS>DM                                        0
# Total_Cholesterol                           207
# Total_Cholesterol_Lab_Date                  197
# Diabetes                                      0
# DM_OnsetDate                               4863
# Depression                                    0
# Depression_OnsetDate                       7884
# HTN                                           0
# HTN_OnsetDate                              3589
# OA                                            0
# OA_OnsetDate                               6860
# COPD                                          0
# COPD_Date                                  9014
# Hypertension_Medications                   2962
# Hypertension_Medications_First_Instance    2963
# Corticosteroids                            7145
# Corticosteroids_first_instance             7145
# Sex                                           0
# leastO(A1c_Date)                           4594
# leastO(DM_OnsetDate)                       4863
# leastO(FBS_Date)                           4589
# LeastOfAll                                 4863
# A1C_BEF_DM                                 4863
# FBS_BEF_DM                                 4863
# Patient_ID                                    0
# DM_Onset_Revised                           4863
# DM_Onset_Revised_1YrPrior                  4863
# DIABETES                                      0
# dtype: int64

# %% [markdown]
# # 2 Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns
import plotly.express as px
import numpy as np
import warnings

# %%
# Check for duplicate rows
duplicate = data[data.duplicated(subset=['Patient_ID'])]

duplicate

# %% [markdown]
# **2.1 Data Visualization**

# %%
# Converting numerical categories to descriptive categories for visualization
data['Diabetes'].replace({0 : 'no', 1 : 'yes'}, inplace = True)
data['Depression'].replace({0 : 'no', 1 : 'yes'}, inplace = True)
data['HTN'].replace({0 : 'no', 1 : 'yes'}, inplace = True)
data['OA'].replace({0 : 'no', 1 : 'yes'}, inplace = True)
data['COPD'].replace({0 : 'no', 1 : 'yes'}, inplace = True)
data['Sex'].replace({'Male' : 'male', 'Female' : 'female'}, inplace = True)

# %%
# Create list of numerical, categorical, multinomial features
target_column = 'Diabetes'
categorical_columns = ['Depression', 'HTN', 'OA', 'COPD', 'Sex']
numerical_columns = ['Age_at_Exam', 'sBP', 'BMI', 'LDL', 'HDL', 'A1c', 'TG', 'FBS', 'Total_Cholesterol']
multinomial_columns = ['Hypertension_Medications', 'Corticosteroids']

# %%
# Checking the difference in distribution of numerical features in two classes

# Create a grid of subplots with 3 rows and 3 columns
fig, axs = plt.subplots(ncols = 3, nrows = 3, figsize = (12, 12))

# Loop over each feature in numerical list
for i, column in enumerate(numerical_columns):
  # Calculate the position for the subplot; x is the row index and y is the column index
  x = i // 3
  y = i % 3

  # Plot a histogram of the feature split by the 'Diabetes' class
  # kde = True adds a Kernal Density Estimate plot to smooth the histogram
  sns.histplot(data, x = column, hue = 'Diabetes', kde = True, palette = 'seismic', ax = axs[x][y])

# Display all the subplots
plt.show()

# %%
# Checking the difference in distribution of categorical features in two classes

# Create a grid of subplots with 2 rows and 3 columns
fig, axs = plt.subplots(ncols = 3, nrows = 2, figsize = (15, 10))

# Loop over each feature in categorical list
for i, column in enumerate(categorical_columns):
  # Calculate the position for the subplot; x is the row index and y is the column index
  x = i // 3
  y = i % 3

  # Plot a histogram of the feature split by the 'Diabetes' class
  # kde = True adds a Kernal Density Estimate plot to smooth the histogram
  sns.countplot(data, x = column, hue = 'Diabetes', palette = 'seismic', ax = axs[x][y])

# Display all the subplots
plt.show()

# %%
# Checking for data imbalance

# Compute the count of each class in the 'Diabetes' column
counts = data['Diabetes'].value_counts()

# Define colors for the pie chart sections
colors = ['#01016f', '#d8031c']

# Construct a pie chart with plotly
# 'names' are the class labels, and 'values' are the counts for each class
fig = px.pie(
    names=counts.index,
    values=counts.values,
    hole=0.5,  # creates a donut-styled pie chart
    title='Distribution of Classes in "Diabetes"',
    color_discrete_sequence=colors
)

# Update the layout of the pie chart for better presentation and clarity
fig.update_layout(
    margin=dict(t=50, b=0, l=0, r=0),
    legend=dict(
        orientation="v",
        yanchor="top",
        y=0.5,
        xanchor="left",
        x=1.05,
        title='Diabetes'
    ),
    title=dict(
        text='Distribution of Classes in "Diabetes"',
        x=0.45,
        xanchor='center',
        y=0.95,
        yanchor='top',
        font=dict(size=16)
    ),
    width=500,
    height=350
)

# Display the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f666eba2-83ed-405b-a5d5-722088292147" class="plotly-graph-div" style="height:350px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f666eba2-83ed-405b-a5d5-722088292147")) {                    Plotly.newPlot(                        "f666eba2-83ed-405b-a5d5-722088292147",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["yes","no"],"legendgroup":"","name":"","showlegend":true,"values":[5139,4861],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"mark ...

# %%
# Converting descriptive categories back to numerical variables
data['Diabetes'].replace({'no' : 0, 'yes' : 1}, inplace = True)
data['Depression'].replace({'no' : 0 , 'yes' : 1}, inplace = True)
data['HTN'].replace({'no' : 0, 'yes': 1}, inplace = True)
data['OA'].replace({'no' : 0, 'yes': 1}, inplace = True)
data['COPD'].replace({'no' : 0, 'yes': 1}, inplace = True)
data['Sex'].replace({'female' : 0, 'male' : 1}, inplace = True)

plt.figure(figsize = (7,6))
sns.heatmap(data[numerical_columns + [target_column]].corr())
# Out:
# <Axes: >

# %% [markdown]
# # 3 Machine Learning Pipeline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns
import plotly.express as px
import warnings

from sklearn.model_selection import GridSearchCV, train_test_split, KFold, cross_validate
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import CategoricalNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.metrics import RocCurveDisplay, roc_curve, accuracy_score, confusion_matrix, roc_auc_score, classification_report

# %%
print(data[numerical_columns].isna().sum())
print(data[categorical_columns].isna().sum())
# Out:
# Age_at_Exam            0
# sBP                    4
# BMI                    0
# LDL                   61
# HDL                   72
# A1c                    0
# TG                    53
# FBS                    0
# Total_Cholesterol    207
# dtype: int64
# Depression    0
# HTN           0
# OA            0
# COPD          0
# Sex           0
# dtype: int64

# %%
numerical_pipeline = Pipeline(steps = [
    ('imputer', IterativeImputer(max_iter = 10, random_state = 42)),
    ('scaler', MinMaxScaler())
])

categorical_pipeline = Pipeline(steps = [
    ('imupter', KNNImputer(n_neighbors = 3)),
    ('one-hot', OneHotEncoder(handle_unknown = 'ignore', sparse = False))
])

# %%
from sklearn.compose import ColumnTransformer

column_transform = ColumnTransformer(transformers = [
    ('numerical_pipeline', numerical_pipeline, numerical_columns),
    ('categorical_pipeline', categorical_pipeline, categorical_columns)
],
                                     remainder = 'drop',
                                     n_jobs = -1)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter = 1000, random_state = 42)
model_pipeline = Pipeline(steps = [
    ('column_transform', column_transform),
    ('model', model)
])

# %%
from sklearn import set_config

set_config(display = 'diagram')
display(model_pipeline)
# Out:
# Pipeline(steps=[('column_transform',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('numerical_pipeline',
#                                                   Pipeline(steps=[('imputer',
#                                                                    IterativeImputer(random_state=42)),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['Age_at_Exam', 'sBP', 'BMI',
#                                                    'LDL', 'HDL', 'A1c', 'TG',
#                                                    'FBS',
#                                                    'Total_Cholesterol']),
#                                                  ('categorical_pipeline',
#                                                   Pipeline(steps=[('imupter',
#                                                                    KNNImputer(n_neighbors=3)),
#                                                                   ('one-hot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['Depression', 'HTN', 'OA',
#                                                    'COPD', 'Sex'])])),
#                 ('model', LogisticRegression(max_iter=1000, random_state=42))])

# %%
# Prepare data
data_x = data[numerical_columns + categorical_columns]
data_y = data[target_column]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.2, random_state=42)

# Cross-Validation using K-Folds (k = 5)
k = 5

# Define hyperparameter tuning
param_grid = {'model__penalty' : ['l1', 'l2'],
              'model__C' : np.logspace(-4, 4, 20),
              'model__solver' : ['liblinear']}

# Initiate grid search
cv = GridSearchCV(model_pipeline, param_grid, cv = k, n_jobs = -1)

# Fit to training set
cv.fit(X_train, y_train)

# Predict the labels of the test set to y_pred
y_pred = cv.predict(X_test)

# Compute and print metrics
print("Accuracy: {}".format(cv.score(X_test, y_test)))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# Accuracy: 0.858
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       952
#            1       0.88      0.85      0.86      1048
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.86      0.86      2000
# weighted avg       0.86      0.86      0.86      2000
#
# Tuned Model Parameters: {'model__C': 0.615848211066026, 'model__penalty': 'l1', 'model__solver': 'liblinear'}

# %%
results = pd.DataFrame(cv.cv_results_)

results[results['rank_test_score'] == 1]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 18       0.986288      0.197938          0.03058        0.007921
#
#    param_model__C param_model__penalty param_model__solver  \
# 18       0.615848                   l1           liblinear
#
#                                                params  split0_test_score  \
# 18  {'model__C': 0.615848211066026, 'model__penalt...           0.848125
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 18            0.86625            0.84625           0.861875
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 18             0.8625            0.857        0.008172                1

# %%
print(X_train[numerical_columns].isna().sum())
print(X_train[categorical_columns].isna().sum())
# Out:
# Age_at_Exam            0
# sBP                    3
# BMI                    0
# LDL                   47
# HDL                   42
# A1c                    0
# TG                    43
# FBS                    0
# Total_Cholesterol    158
# dtype: int64
# Depression    0
# HTN           0
# OA            0
# COPD          0
# Sex           0
# dtype: int64

# %%
classes = data['Diabetes'].unique()

# Plotting the confusion matrix
sns.heatmap(confusion_matrix(y_test, y_pred, labels = classes), annot = True,
            xticklabels = classes, yticklabels = classes, cmap = 'Blues',
            fmt = 'g')

plt.xlabel('Predicted')
plt.ylabel('Actual')
title = 'Confusion Matrix'
plt.title(title)

plt.show()

# Compute and print metrics
print("Accuracy: {}".format(cv.score(X_test, y_test)))
print(classification_report(y_test, y_pred))
print("Tuned Model Parameters: {}".format(cv.best_params_))
# Out:
# Accuracy: 0.858
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       952
#            1       0.88      0.85      0.86      1048
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.86      0.86      2000
# weighted avg       0.86      0.86      0.86      2000
#
# Tuned Model Parameters: {'model__C': 0.615848211066026, 'model__penalty': 'l1', 'model__solver': 'liblinear'}

# %%
from sklearn.metrics import roc_curve

plot_roc_curve(cv, X)
